# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahan402/DailyPractice/blob/main/Lecture_42_Groupby_on_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dframe = pd.DataFrame({'k1':['X','X','Y','Y','Z'],
                       'k2':['alpha','beta','alpha','beta','alpha'],
                       'dataset1':np.random.randn(5),
                       'dataset2':np.random.randn(5)})

# %%
dframe
# Out:
#   k1     k2  dataset1  dataset2
# 0  X  alpha -1.552080  1.298328
# 1  X   beta  0.187047  0.140112
# 2  Y  alpha  1.422705 -1.425445
# 3  Y   beta -0.455076 -0.141012
# 4  Z  alpha -0.063600  0.046261

# %%
group1 = dframe['dataset1'].groupby(dframe['k1'])

# %%
print(group1)

# %%
group1.mean()
# Out:
# k1
# X   -0.682517
# Y    0.483815
# Z   -0.063600
# Name: dataset1, dtype: float64

# %%
cities = np.array(['NY','LA','LA','NY','NY'])

month = np.array(['JAN',"FEB",'JAN','FEB','JAN'])

# %%
dframe['dataset1'].groupby([cities,month]).mean()
# Out:
# LA  FEB    0.187047
#     JAN    1.422705
# NY  FEB   -0.455076
#     JAN   -0.807840
# Name: dataset1, dtype: float64

# %%
dframe
# Out:
#   k1     k2  dataset1  dataset2
# 0  X  alpha -1.552080  1.298328
# 1  X   beta  0.187047  0.140112
# 2  Y  alpha  1.422705 -1.425445
# 3  Y   beta -0.455076 -0.141012
# 4  Z  alpha -0.063600  0.046261

# %%
dframe.groupby('k1').mean()
# Out:
#     dataset1  dataset2
# k1
# X  -0.682517  0.719220
# Y   0.483815 -0.783228
# Z  -0.063600  0.046261

# %%
dframe.groupby(['k1','k2']).mean()
# Out:
#           dataset1  dataset2
# k1 k2
# X  alpha -1.552080  1.298328
#    beta   0.187047  0.140112
# Y  alpha  1.422705 -1.425445
#    beta  -0.455076 -0.141012
# Z  alpha -0.063600  0.046261

# %%
dframe.groupby(['k1']).size()
# Out:
# k1
# X    2
# Y    2
# Z    1
# dtype: int64

# %%
dframe
# Out:
#   k1     k2  dataset1  dataset2
# 0  X  alpha -1.552080  1.298328
# 1  X   beta  0.187047  0.140112
# 2  Y  alpha  1.422705 -1.425445
# 3  Y   beta -0.455076 -0.141012
# 4  Z  alpha -0.063600  0.046261

# %%
for name,group in dframe.groupby('k1'):
  print ("this is the %s group" %name)
  print (group)
  print ('\n')
# Out:
# this is the X group
#   k1     k2  dataset1  dataset2
# 0  X  alpha -1.552080  1.298328
# 1  X   beta  0.187047  0.140112
#
#
# this is the Y group
#   k1     k2  dataset1  dataset2
# 2  Y  alpha  1.422705 -1.425445
# 3  Y   beta -0.455076 -0.141012
#
#
# this is the Z group
#   k1     k2  dataset1  dataset2
# 4  Z  alpha   -0.0636  0.046261

# %%
for (k1,k2), group in dframe.groupby(['k1','k2']):
  print('key1 = %s key2 = %s' %(k1,k2))
  print(group)
  print('\n')
# Out:
# key1 = X key2 = alpha
#   k1     k2  dataset1  dataset2
# 0  X  alpha  -1.55208  1.298328
#
#
# key1 = X key2 = beta
#   k1    k2  dataset1  dataset2
# 1  X  beta  0.187047  0.140112
#
#
# key1 = Y key2 = alpha
#   k1     k2  dataset1  dataset2
# 2  Y  alpha  1.422705 -1.425445
#
#
# key1 = Y key2 = beta
#   k1    k2  dataset1  dataset2
# 3  Y  beta -0.455076 -0.141012
#
#
# key1 = Z key2 = alpha
#   k1     k2  dataset1  dataset2
# 4  Z  alpha   -0.0636  0.046261

# %%
group_dict = dict(list(dframe.groupby('k1')))

# %%
group_dict['X']
# Out:
#   k1     k2  dataset1  dataset2
# 0  X  alpha -1.552080  1.298328
# 1  X   beta  0.187047  0.140112

# %%
group_dict_axis1 = dict(list(dframe.groupby(dframe.dtypes,axis=1)))

# %%
group_dict_axis1
# Out:
# {dtype('float64'):    dataset1  dataset2
#  0 -1.552080  1.298328
#  1  0.187047  0.140112
#  2  1.422705 -1.425445
#  3 -0.455076 -0.141012
#  4 -0.063600  0.046261, dtype('O'):   k1     k2
#  0  X  alpha
#  1  X   beta
#  2  Y  alpha
#  3  Y   beta
#  4  Z  alpha}

# %%
dataset2_group = dframe.groupby(['k1','k2'])[['dataset1']]
dataset2_group.mean()
# Out:
#           dataset1
# k1 k2
# X  alpha -1.552080
#    beta   0.187047
# Y  alpha  1.422705
#    beta  -0.455076
# Z  alpha -0.063600
