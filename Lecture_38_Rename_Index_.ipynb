# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahan402/DailyPractice/blob/main/Lecture_38_Rename_Index_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dframe = pd.DataFrame(np.arange(12).reshape(3,4),
                      index = ['NY','LA','SF'],
                      columns = ['A','B','C','D'])

# %%
dframe
# Out:
#     A  B   C   D
# NY  0  1   2   3
# LA  4  5   6   7
# SF  8  9  10  11

# %%
dframe.index.map(str.lower)
# Out:
# Index(['ny', 'la', 'sf'], dtype='object')

# %%
dframe.index = dframe.index.map(str.lower)

# %%
dframe
# Out:
#     A  B   C   D
# ny  0  1   2   3
# la  4  5   6   7
# sf  8  9  10  11

# %%
dframe.rename(index = str.title,columns = str.lower)
# Out:
#     a  b   c   d
# Ny  0  1   2   3
# La  4  5   6   7
# Sf  8  9  10  11

# %%
dframe.rename(index= {'ny':'NEW YORK'},
              columns = {'A':'ALPHA'})
# Out:
#           ALPHA  B   C   D
# NEW YORK      0  1   2   3
# la            4  5   6   7
# sf            8  9  10  11

# %%
dframe
# Out:
#     A  B   C   D
# ny  0  1   2   3
# la  4  5   6   7
# sf  8  9  10  11

# %%
dframe.rename(index= {'ny':'NEW YORK'},inplace =True)

# %%
dframe
# Out:
#           A  B   C   D
# NEW YORK  0  1   2   3
# la        4  5   6   7
# sf        8  9  10  11
