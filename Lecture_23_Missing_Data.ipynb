# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahan402/DailyPractice/blob/main/Lecture_23_Missing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
data =  Series(['one','two',np.nan,'four'])

# %%
data
# Out:
# 0     one
# 1     two
# 2     NaN
# 3    four
# dtype: object

# %%
data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data.dropna()
# Out:
# 0     one
# 1     two
# 3    four
# dtype: object

# %%
dframe = DataFrame([[1,2,3],[np.nan,5,6],[7,np.nan,9],[np.nan,np.nan,np.nan,np.nan]])

# %%
dframe
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0 NaN
# 1  NaN  5.0  6.0 NaN
# 2  7.0  NaN  9.0 NaN
# 3  NaN  NaN  NaN NaN

# %%
clean_dframe = dframe.dropna()

# %%
clean_dframe
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
dframe.dropna(how='all', axis=1) #for columns
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0
# 3  NaN  NaN  NaN

# %%
dframe.dropna(how='all') #for rows
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0 NaN
# 1  NaN  5.0  6.0 NaN
# 2  7.0  NaN  9.0 NaN

# %%
npn = np.nan
dframe2 = DataFrame([[1,2,3,npn],[2,npn,5,6],[npn,7,npn,9],[1,npn,npn,npn]])

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0
# 3  1.0  NaN  NaN  NaN

# %%
dframe2.dropna(thresh=2)
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0

# %%
dframe2.dropna(thresh=3)
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0
# 3  1.0  NaN  NaN  NaN

# %%
dframe.fillna(1)
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  1.0
# 1  1.0  5.0  6.0  1.0
# 2  7.0  1.0  9.0  1.0
# 3  1.0  1.0  1.0  1.0

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0
# 3  1.0  NaN  NaN  NaN

# %%
dframe2.fillna({0:0,1:1,2:2,3:3})
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  3.0
# 1  2.0  1.0  5.0  6.0
# 2  0.0  7.0  2.0  9.0
# 3  1.0  1.0  2.0  3.0

# %%
dframe2.fillna(0,inplace=True)

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  0.0
# 1  2.0  0.0  5.0  6.0
# 2  0.0  7.0  0.0  9.0
# 3  1.0  0.0  0.0  0.0
