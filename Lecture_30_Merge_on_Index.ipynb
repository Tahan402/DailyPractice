# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahan402/DailyPractice/blob/main/Lecture_30_Merge_on_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_left = pd.DataFrame({'key':['X','Y','Z','X','Y'],
                        'data':range(5)})

# %%
df_left
# Out:
#   key  data
# 0   X     0
# 1   Y     1
# 2   Z     2
# 3   X     3
# 4   Y     4

# %%
df_right = pd.DataFrame({'group_data':[10,20]},index = ['X','Y'])

# %%
df_right
# Out:
#    group_data
# X          10
# Y          20

# %%
pd.merge(df_left,df_right,left_on='key',right_index= True)
# Out:
#   key  data  group_data
# 0   X     0          10
# 3   X     3          10
# 1   Y     1          20
# 4   Y     4          20

# %%
df_left_hr = pd.DataFrame({'key1':['SF','SF','SF','LA','LA'],
                           'key2':[10,20,30,20,30],
                           'data_set' : np.arange(5)})

# %%
df_left_hr
# Out:
#   key1  key2  data_set
# 0   SF    10         0
# 1   SF    20         1
# 2   SF    30         2
# 3   LA    20         3
# 4   LA    30         4

# %%
df_right_hr = pd.DataFrame(np.arange(10).reshape(5,2),
                           index= [['LA','LA','SF','SF','SF'],
                                   [20,10,10,10,20]],
                           columns = ['col_1','col_2'])

# %%
df_right_hr
# Out:
#        col_1  col_2
# LA 20      0      1
#    10      2      3
# SF 10      4      5
#    10      6      7
#    20      8      9

# %%
pd.merge(df_left_hr,df_right_hr, left_on=['key1','key2'],right_index=True)
# Out:
#   key1  key2  data_set  col_1  col_2
# 0   SF    10         0      4      5
# 0   SF    10         0      6      7
# 1   SF    20         1      8      9
# 3   LA    20         3      0      1

# %%
df_left.join(df_right)
# Out:
#   key  data  group_data
# 0   X     0         NaN
# 1   Y     1         NaN
# 2   Z     2         NaN
# 3   X     3         NaN
# 4   Y     4         NaN
